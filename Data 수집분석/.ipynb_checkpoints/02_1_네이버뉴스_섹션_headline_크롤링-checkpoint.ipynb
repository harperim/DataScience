# %% [markdown]
# ### 네이버뉴스 섹션별 Headline 크롤링
# - 정치,경제,사회,생활/문화, IT/과학, 세계

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import pandas as pd
import bs4
import requests
from urllib.request import urlopen

# %%
# 각 섹션별 링크주소 파일 가져오기
df_menu = pd.read_csv('./crawl_data/naver_news_section.csv',index_col=0)
df_menu.head()
# Out:
#   section                                               link
# 0      정치  https://news.naver.com/main/main.naver?mode=LS...
# 1      경제  https://news.naver.com/main/main.naver?mode=LS...
# 2      사회  https://news.naver.com/main/main.naver?mode=LS...
# 3   생활/문화  https://news.naver.com/main/main.naver?mode=LS...
# 4   IT/과학  https://news.naver.com/main/main.naver?mode=LS...

# %% [markdown]
# ### 경제 섹션을 예시로 코드를 작성 후 함수화 진행

# %%
url = df_menu['link'][1]  # 경제
url
# Out:
# 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101'

# %%
# 경제 섹션 소스 요청
res = urlopen(url)
html = res.read()  # binary로 들어옴
# html

# %%
bs_obj = bs4.BeautifulSoup(html, 'html.parser')
bs_obj
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="경제 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image">
# <meta content="증권, 금융, 부동산, 기업, 국제 등 경제 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="경제 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="증권, 금융, 부동산, 기업, 국제 등 경제 분야 뉴스 제공" name="twitter:description"/>
# <title>경제 홈 : 네이버 뉴스	</title>
# <link href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Wed Aug 09 03:24:30 KST 2023";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20230803_112201/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li class="on"><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/opinion/home"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# <li><a class="nclicks(lnb.algo)" href="https://media.naver.com/algorithm"><span class="tx">알고리즘 안내</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>08</strong>.<strong>09</strong><span class="day">(수)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h3"><a class="nclicks(lmn_eco.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101">경제</a></h2>
# <ul class="nav">
# <li><a class="snb_s20 nclicks(lmn_eco.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=259">금융 </a></li>
# <li><a class="snb_s25 nclicks(lmn_eco.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=258">증권 </a></li>
# <li><a class="snb_s119 nclicks(lmn_eco.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=261">산업/재계 </a></li>
# <li><a class="snb_s21 nclicks(lmn_eco.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=771">중기/벤처 </a></li>
# <li><a class="snb_s22 nclicks(lmn_eco.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=260">부동산 </a></li>
# <li><a class="snb_s23 nclicks(lmn_eco.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=262">글로벌 경제 </a></li>
# <li><a class="snb_s24 nclicks(lmn_eco.mnl,,7)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=310">생활경제 </a></li>
# <li><a class="snb_s19 nclicks(lmn_eco.mnl,,8)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=101&amp;sid2=263">경제 일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_eco.pmb,,1)" href="https://media.naver.com/algorithm"><img alt="AI 알고리즘 안내" height="74" src="https://imgnews.pstatic.net/image/upload/item/2023/07/10/184436024_banner_left.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_eco.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="javascript:;">
#                         헤드라인 뉴스<i class="cluster_title_icon">안내</i></a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
# <p>각 헤드라인의 기사와 배열 순서는 개인화를 반영해 자동 추천되어 제공됩니다.<br/>기사 수량이 표기된 기사 우측 하단의 파란색 아이콘을 클릭하면 기사묶음을 확인할 수 있고 기사묶음과 기사묶음 타이틀도 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.</p>
# <a class="cluster_to_algorithm_detail_link" href="https://media.naver.com/algorithm">알고리즘 자세히 보기</a>
# </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="section_headline">
# <ul class="sh_list">
# <li class="sh_item _cluster_content">
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/009/0005170036?sid=101">공정위·권익위까지 총동원해 조사 … 與 "LH 카르텔 철폐 입법 속도"</a>
# <div class="sh_text_lede">당정, 입주민 불안 달래기 입찰담합 조사·공익신고 접수 '철근 누락' 시공사 13곳 부당 하도급까지 조사 확대 ◆ LH 부실시공 후폭풍 ◆ 정부가 철근 누락 등 부실 시공으로 드러난 건설업계의 '이권 나눠먹 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news009,0005170036',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">매일경제</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308071210_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=009&amp;aid=0005170036"><span class="sh_head_more_icon_num">46</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# <li class="sh_item _cluster_content">
# <div class="sh_thumb">
# <div class="sh_thumb_inner">
# <a class="sh_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/008/0004922821?sid=101">
# <img alt="" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/008/2023/08/08/4922821.jpg?type=nf132_90" width="106"/>
# </a>
# </div>
# </div>
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/008/0004922821?sid=101">美 금리 인하…시장은 내년 3월 vs 연준은 내년 하반기[오미주]</a>
# <div class="sh_text_lede">'오미주'는 '오늘 주목되는 미국 주식'의 줄인 말입니다. 주가에 영향을 미칠 만한 이벤트나 애널리스트들의 언급이 많았던 주식을 뉴욕 증시 개장 전에 정 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news008,0004922821',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">머니투데이</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308080600_00000057&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=008&amp;aid=0004922821"><span class="sh_head_more_icon_num">19</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# <li class="sh_item _cluster_content">
# <div class="sh_thumb">
# <div class="sh_thumb_inner">
# <a class="sh_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/015/0004877450?sid=101">
# <img alt="" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/015/2023/08/08/4877450.jpg?type=nf132_90" width="106"/>
# </a>
# </div>
# </div>
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/015/0004877450?sid=101">편의점 이익 줄었지만 슈퍼·호텔 선전…GS리테일, 2분기 영업익 94% '껑충' [종합]</a>
# <div class="sh_text_lede">편의점(GS25)과 슈퍼마켓(GS더프레시), 홈쇼핑(GS샵) 등을 운영하는 종합유통기업 GS리테일이 올해 2분기 영업이익 기준으로 증권가 예상을 큰 폭으 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news015,0004877450',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">한국경제</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308081410_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=015&amp;aid=0004877450"><span class="sh_head_more_icon_num">43</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# <li class="sh_item _cluster_content">
# <div class="sh_thumb">
# <div class="sh_thumb_inner">
# <a class="sh_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/009/0005169978?sid=101">
# <img alt="" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/009/2023/08/08/5169978.jpg?type=nf132_90" width="106"/>
# </a>
# </div>
# </div>
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/009/0005169978?sid=101">오전에 떴던 초전도체 테마株, 오후에 '와르르'</a>
# <div class="sh_text_lede">LK-99는 초전도체 아니다" 美메릴랜드대 연구소 발표 서남 22% 오르다 하한가로 금감원장 "테마주 과열돼" 허위풍문 집중 점검 예고 초전도체 테마주가 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news009,0005169978',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">매일경제</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308021050_00000003&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=009&amp;aid=0005169978"><span class="sh_head_more_icon_num">43</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# <li class="sh_item _cluster_content">
# <div class="sh_thumb">
# <div class="sh_thumb_inner">
# <a class="sh_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/029/0002818151?sid=101">
# <img alt="" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2023/08/08/2818151.jpg?type=nf132_90" width="106"/>
# </a>
# </div>
# </div>
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/029/0002818151?sid=101">차기 KB금융 회장 1차 후보 6명 오늘 확정...`용퇴` 윤종규, “이사회가 탁월한 후보 선임할 것”</a>
# <div class="sh_text_lede">'명예로운 퇴진'을 선언한 윤종규 KB금융회장이 "이사회가 그룹의 지속 성장을 이끌 탁월한 후보를 선임할 것"이라는 기대감을 담은 서한을 주요 주주들에게 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news029,0002818151',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">디지털타임스</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308031110_00000740&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=029&amp;aid=0002818151"><span class="sh_head_more_icon_num">73</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# <li class="sh_item _cluster_content" style="display: none">
# <div class="sh_thumb">
# <div class="sh_thumb_inner">
# <a class="sh_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/018/0005547086?sid=101">
# <img alt="" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/018/2023/08/08/5547086.jpg?type=nf132_90" width="106"/>
# </a>
# </div>
# </div>
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/018/0005547086?sid=101">'소비 절벽 여파' 현대백화점, 2분기 영업이익 21.9%↓(종합)</a>
# <div class="sh_text_lede">현대백화점(069960)이 고물가에 꺾인 소비 심리와 지난해 호실적에 따른 역기저 효과 여파로 2분기 매출과 영업이익이 모두 줄었다. 다만 하반기부터 면 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news018,0005547086',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">이데일리</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308081520_00000001&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=018&amp;aid=0005547086"><span class="sh_head_more_icon_num">26</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# <li class="sh_item _cluster_content" style="display: none">
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/052/0001920444?sid=101">2분기 제조업 국내 공급 1.6% 감소...수입 3년 만에 감소세 전환</a>
# <div class="sh_text_lede">올해 2분기 제조업 제품의 국내 공급이 1년 전보다 감소한 것으로 나타났습니다. 수입 제품 공급은 3년 만에 감소세로 돌아섰습니다. 통계청은 지난 2분기 제조업 국내 공급지수가 지난해 같은 기간보다 1.6% …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news052,0001920444',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">YTN</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308081210_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=052&amp;aid=0001920444"><span class="sh_head_more_icon_num">26</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# <li class="sh_item _cluster_content" style="display: none">
# <div class="sh_thumb">
# <div class="sh_thumb_inner">
# <a class="sh_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/003/0012020204?sid=101">
# <img alt="" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/003/2023/08/08/12020204.jpg?type=nf132_90" width="106"/>
# </a>
# </div>
# </div>
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/003/0012020204?sid=101">진에어, 2Q 영업익 178억 흑자 전환…상반기 '역대 최대'</a>
# <div class="sh_text_lede">진에어는 별도기준 올 2분기 실적으로 매출액 2590억원, 영업이익 178억원을 달성했다고 8일 공시했다. 매출액은 전년동기대비 105% 증가했고, 영업 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news003,0012020204',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">뉴시스</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308081600_00000018&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=003&amp;aid=0012020204"><span class="sh_head_more_icon_num">14</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# <li class="sh_item _cluster_content" style="display: none">
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/014/0005054391?sid=101">LG엔솔, 中에 배터리 재활용공장 짓는다</a>
# <div class="sh_text_lede">LG에너지솔루션이 중국 1위 코발트 생산업체 화유코발트와 배터리 리사이클 합작법인(JV)를 설립했다. LG에너지솔루션은 지난 7일 중국 저장성에 위치한 화유코발트 본사에서 배터리 리사이클 합작법인 계약 체결 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news014,0005054391',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">파이낸셜뉴스</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308080820_00002106&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=014&amp;aid=0005054391"><span class="sh_head_more_icon_num">44</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# <li class="sh_item _cluster_content" style="display: none">
# <div class="sh_thumb">
# <div class="sh_thumb_inner">
# <a class="sh_thumb_link nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/015/0004877555?sid=101">
# <img alt="" height="72" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/015/2023/08/08/4877555.jpg?type=nf132_90" width="106"/>
# </a>
# </div>
# </div>
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/015/0004877555?sid=101">항공유 판매, 코로나 이전 수준 회복</a>
# <div class="sh_text_lede">정유 4사 수익성의 한 축을 담당하는 항공유 판매가 코로나19 이전 수준으로 회복하고 있다. 항공유 판매는 각사 매출의 10~15%에 불과하지만, 정제마 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news015,0004877555',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">한국경제</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308071700_00001840&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=015&amp;aid=0004877555"><span class="sh_head_more_icon_num">8</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="cluster _news_cluster_more_layer">
# <div class="cluster_more">
# <a class="cluster_more_inner _news_cluster_more_btn nclicks(cls_eco.clsmore)" href="#">헤드라인 더보기</a>
# </div>
# </div>
# </div>
# <div class="cluster">
# <div class="cluster_group">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_left nclicks(eco.sert)" href="/hotissue/main?sid1=163&amp;cid=2001222">
# <div class="cluster_head_go as_series">연재보기</div>
# <h2 class="cluster_head_topic">마켓분석</h2>
# </a>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(eco.sera)" href="https://n.news.naver.com/mnews/hotissue/article/665/0000001414?type=series&amp;cid=2001222">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/665/2023/08/07/0000001414_001_20230807092601684.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(eco.sera)" href="https://n.news.naver.com/mnews/hotissue/article/665/0000001414?type=series&amp;cid=2001222">중소 브랜드 펄펄 나는데… 화장품 빅2 엇갈린 실적 [분석+]</a>
# <div class="cluster_text_lede">화장품 시장의 희비가 엇갈리고 있다. 무엇보다 국내 화장품 시장 빅2로 꼽히는 아모레퍼시픽과 LG생활건강이 서로 다른 성적표를 받 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news665,params:{sid1:'101'},0000001414',nclicks:'cmt.count'}">
# <div class="cluster_text_press">더스쿠프</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news665,0000001400',params:{sid1:'101'},nclicks:'cmt.count'}">
# <div class="cluster_text_press">더스쿠프</div>
# </div>
# <a class="cluster_text_headline nclicks(eco.sera)" href="https://n.news.naver.com/mnews/hotissue/article/665/0000001400?type=series&amp;cid=2001222">"끼리끼리 공사" 부실한 무량판에 카르텔 숨어있나 [분석+]</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news665,0000001399',params:{sid1:'101'},nclicks:'cmt.count'}">
# <div class="cluster_text_press">더스쿠프</div>
# </div>
# <a class="cluster_text_headline nclicks(eco.sera)" href="https://n.news.naver.com/mnews/hotissue/article/665/0000001399?type=series&amp;cid=2001222">가뜩이나 비싼데… 원윳값 올랐으니 빵값이 걱정이네 [분석+]</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news665,0000001390',params:{sid1:'101'},nclicks:'cmt.count'}">
# <div class="cluster_text_press">더스쿠프</div>
# </div>
# <a class="cluster_text_headline nclicks(eco.sera)" href="https://n.news.naver.com/mnews/hotissue/article/665/0000001390?type=series&amp;cid=2001222">착공과 준공의 간극 … 주택 공급량 널뛰는 까닭 [분석+]</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="section_ad" id="glad_ad_newslist">
# <script>
#             gladsdk.cmd.push(function () {
#                 var adSlot = gladsdk.findAdSlot("glad_ad_newslist");
#
#                 adSlot.setCustomParam("sid1", 101);
#                 gladsdk.displayAd(adSlot);
#             })
#         </script>
# </div>
# <a id="mainNewsComponentId"></a>
# <h4 class="blind">뉴스 더보기</h4>
# <div class="section_body" id="section_body"></div>
# <div class="airs" id="airs_explain_text">
# <div class="airs_info">
# <p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>
# <a class="airs_info_to_algorithm_detail" href="https://media.naver.com/algorithm">알고리즘 안내</a>
# </div>
# </div>
# <div class="paging" id="paging"></div>
# </div>
# <script type="text/javascript">
#     window.onload = function() {
#         var selected_item = jindo.$('_');
#         if (selected_item != null) {
#             selected_item.className = "highlight";
#             news.section.ScrollingManager.scroll('');
#         }
#         news.util.CommentListCountManager.view();
#     }
#
#     new NewsCluster().init(101);
#
#     news.section.MainIssueCollectManager.init({
#         id : 101,
#         mediaOneDomain : 'https://n.news.naver.com'
#     });
#     news.section.IssueKeywordManager.init();
# </script>
# </div>
# </td>
# <td class="aside">
# <div class="aside">
# <div class="section _officeTopRanking1087474">
# <h4>언론사별 가장 많이 본 뉴스</h4>
# <button class="section_info_icon nclicks('rig.renws2i') _rankingInfoButton" type="button">안내</button>
# <div class="section_info_layer _rankingInfoLayer" style="display: none">각 언론사의 가장 많이 본 기사 1건을 제공합니다. <button class="section_info_layer_close _rankingInfoCloseButton nclicks('rig.renws2x')" type="button"><span>닫기</span></button></div>
# <p class="section_sub_txt">오전 12시~오전 1시까지 집계한 결과입니다.</p>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList0" style="display: block">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/001/0014120198?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/001/2023/08/08/14120198.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/001/0014120198?ntype=RANKING&amp;sid=001">여가부 장관 "잼버리 사태, 위기대응 역량 보여주는 시점" …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=001"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/001/2020/08/11/logo_001_56_20200811154916.png" width="16"/></span>연합뉴스</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/087/0000987788?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/087/2023/08/08/987788.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/087/0000987788?ntype=RANKING&amp;sid=001">600mm 이상 폭우… 태풍 '카눈' 위기경보 최고단계 ' …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=087"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2019/08/22/logo_087_56_20190822110222.png" width="16"/></span>강원일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/055/0001079870?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/055/2023/08/08/1079870.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/055/0001079870?ntype=RANKING&amp;sid=001">느리고 강한 태풍 '카눈'…상륙해도 세력 유지되는 이유</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=055"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2020/10/07/logo_055_56_20201007141807.jpg" width="16"/></span>SBS</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/215/0001118122?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/215/2023/08/08/1118122.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/215/0001118122?ntype=RANKING&amp;sid=001">"알고 나면 못먹어요"...美 맥도날드 직원이 저격한 음료 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=215"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/215/2020/08/12/logo_215_56_20200812134433.png" width="16"/></span>한국경제TV</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/022/0003842841?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/022/2023/08/08/3842841.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/022/0003842841?ntype=RANKING&amp;sid=001">“압구정 롤스로이스에 치인 여동생 아예 의식 없어…더 안  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=022"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/022/2018/07/18/logo_022_56_20180718152618.png" width="16"/></span>세계일보</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList5" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/437/0000354600?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/437/2023/08/08/354600.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/437/0000354600?ntype=RANKING&amp;sid=001">서쪽으로 틀어진 태풍 '카눈'…물폭탄 몰고 수도권 관통한다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=437"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2023/07/17/logo_437_56_20230717153920.png" width="16"/></span>JTBC</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/023/0003780485?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/023/2023/08/08/3780485.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/023/0003780485?ntype=RANKING&amp;sid=001">“에스파 윈터, 칼로 살해” 연예인 살인 예고까지 나왔다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=023"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/023/2020/04/29/logo_023_56_20200429140429.png" width="16"/></span>조선일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/009/0005170146?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/009/2023/08/08/5170146.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/009/0005170146?ntype=RANKING&amp;sid=001">침구 들춰봤다가 경악했다...‘빈대 소굴’에서 보낸 하루, …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=009"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/009/2018/07/20/logo_009_56_20180720194820.png" width="16"/></span>매일경제</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/011/0004224188?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/011/2023/08/08/4224188.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/011/0004224188?ntype=RANKING&amp;sid=001">"어떻게 용케 걸었네"…온몸 칭칭 감은 테이프 벗기자 아이 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=011"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_56_20220729150242.jpg" width="16"/></span>서울경제</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/015/0004877675?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/015/2023/08/08/4877675.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/015/0004877675?ntype=RANKING&amp;sid=001">잼버리 대원들 줄 복숭아인데…두 박스 몰래 훔쳐간 부부</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=015"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/015/2020/08/11/logo_015_56_20200811194037.png" width="16"/></span>한국경제</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList10" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/374/0000346700?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/374/2023/08/08/346700.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/374/0000346700?ntype=RANKING&amp;sid=001">주담대 왜, 얼마나 더 오르나…가계부채 '빨간불'</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=374"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/374/2020/12/29/logo_374_56_20201229152554.jpg" width="16"/></span>SBS Biz</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/031/0000764374?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/031/2023/08/08/764374.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/031/0000764374?ntype=RANKING&amp;sid=001">성일종 "BTS, 잼버리 K팝 공연 참여해야"…아미 "왜  …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=031"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/031/2020/11/27/logo_031_56_20201127145235.jpg" width="16"/></span>아이뉴스24</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/032/0003241346?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/032/2023/08/08/3241346.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/032/0003241346?ntype=RANKING&amp;sid=001">남성 암 발생률 3위 ‘이 암’··· 전이되면 생존율 30 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=032"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/032/2022/12/05/logo_032_56_20221205150153.png" width="16"/></span>경향신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/422/0000613349?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/422/2023/08/08/613349.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/422/0000613349?ntype=RANKING&amp;sid=001">전례 없는 경로…태풍 '카눈' 강한데 오래 머문다</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=422"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/422/2019/11/29/logo_422_56_20191129165529.jpg" width="16"/></span>연합뉴스TV</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/081/0003383364?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/081/2023/08/08/3383364.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/081/0003383364?ntype=RANKING&amp;sid=001">日소방관들, 회식 중 벌거벗고 여성대원 앞에서 …‘성폭력’ …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=081"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/081/2022/01/05/logo_081_56_20220105195830.png" width="16"/></span>서울신문</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList15" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/005/0001629515?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/005/2023/08/09/1629515.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/005/0001629515?ntype=RANKING&amp;sid=001">[단독] 법무부, 내담자 성관계 마약중독상담가 출강 제한</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=005"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/005/2018/07/18/logo_005_56_20180718152218.png" width="16"/></span>국민일보</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/018/0005547208?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/018/2023/08/08/5547208.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/018/0005547208?ntype=RANKING&amp;sid=001">“출국날 에스파 윈터 죽이겠다” 살인 예고…인천공항 발칵</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=018"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/018/2018/07/18/logo_018_56_20180718152418.png" width="16"/></span>이데일리</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/366/0000922866?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/366/2023/08/08/922866.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/366/0000922866?ntype=RANKING&amp;sid=001">‘0원짜리 회사’ 덕에 초전도체 테마 타고 시총 5배 불어 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=366"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/366/2020/12/23/logo_366_56_20201223182636.png" width="16"/></span>조선비즈</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/277/0005297608?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/277/2023/08/08/5297608.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/277/0005297608?ntype=RANKING&amp;sid=001">"연봉 대폭 인상에 주4일제까지"…공무원 기피에 파격 조치 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=277"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/277/2018/07/18/logo_277_56_20180718153218.png" width="16"/></span>아시아경제</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/052/0001920608?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/052/2023/08/08/1920608.jpg?type=nf88_60" width="88"/>
# <strong class="r_ico r_vod_small">동영상기사</strong>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/052/0001920608?ntype=RANKING&amp;sid=001">[날씨] 태풍 '카눈' 수도권 통과...진로 서편하는 이유 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=052"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/052/2021/10/01/logo_052_56_20211001183149.png" width="16"/></span>YTN</a>
# </div>
# </div>
# </div>
# </li>
# </ul>
# <ul class="section_list_ranking_press _rankingList" id="_rankingList20" style="display: none">
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/030/0003124046?ntype=RANKING&amp;sid=001">
# <img alt="" height="60" onerror="this.src='https://ssl.pstatic.net/static.news/image/news/errorimage/noimage_88x60.png';" src="https://mimgnews.pstatic.net/image/origin/030/2023/08/08/3124046.jpg?type=nf88_60" width="88"/>
# </a>
# <div class="list_text_wrap">
# <div class="list_text">
# <div class="list_text_inner">
# <a class="list_tit nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/030/0003124046?ntype=RANKING&amp;sid=001">태풍 '카눈' 10일 통영 인근 상륙… 韓 관통 “비상 걸 …</a>
# <a class="list_press nclicks('rig.renws2pname')" href="/main/ranking/office.naver?officeId=030"><span class="list_press_thumb"><img alt="" height="16" src="https://mimgnews.pstatic.net/image/upload/office_logo/030/2018/07/20/logo_030_56_20180720194820.png" width="16"/></span>전자신문</a>
# </div>
# </div>
# </div>
# </li>
# <li>
# <a class="ranking_thumb nclicks('rig.renws2')" href="https://n.news.naver.com/mnews/ranking/article/082/0001226180?ntype=RANKING&amp;sid=001">
# ...
#
#                     rankingList.hide();
#                     nextRankingList.show();
#
#                     break;
#                 }
#             }
#         }
#     });
#
#     window.addEventListener("load", function() {
#         var officeTopRanking = jindo.$$.getSingle("._officeTopRanking1087474");
#         if (officeTopRanking) {
#             new OfficeTopRankingManager(officeTopRanking);
#         }
#     });
# </script>
# <div class="side_ad" id="glad_ad_sidebox"></div>
# <div class="section as_finance">
# <div class="as_finance_tit">
# <ul class="as_finance_tab" role="tab_list">
# <li class="on" id="tab_0"><a aria-selected="true" class="tab_stock" href="#" onclick="return false;" onkeydown="finance_tab_focus(this);" role="tab"><strong>증권</strong></a></li>
# <li id="tab_1"><a aria-selected="false" class="tab_exchange" href="#" onclick="return false;" onkeydown="finance_tab_focus(this);" role="tab">환율</a></li>
# </ul>
# <h4 class="blind">증권</h4>
# </div>
# <div id="finance_tab_0">
# <div class="as_finance_content_wrap">
# <div class="as_finance_content">
# <table cellpadding="0" cellspacing="0" class="table_finance">
# <caption class="blind">
#       코스피,코스닥 지수
#      </caption>
# <colgroup>
# <col width="66">
# <col width="76">
# <col>
# <col/>
# </col></col></col></colgroup>
# <tbody>
# <tr>
# <th scope="row"><a class="visit nclicks(rig.finance)" href="https://finance.naver.com/sise/sise_index.naver?code=KOSPI" target="_blank">코스피</a></th>
# <td class="num">2,573.98</td>
# <td class="num dn"><i>하락</i>6.73</td>
# <td class="num fluctuation">-0.26%</td>
# </tr>
# <tr>
# <th scope="row"><a class="visit" href="https://finance.naver.com/sise/sise_index.naver?code=KOSDAQ" target="_blank">코스닥</a></th>
# <td class="num">892.34</td>
# <td class="num dn"><i>하락</i>5.88</td>
# <td class="num fluctuation">-0.65%</td>
# </tr>
# </tbody>
# </table>
# <form action="https://finance.naver.com/search/search.naver" method="get" onsubmit="return stock_search_1079042(); return false;" target="_blank">
# <fieldset class="finance">
# <legend>증권 종목검색</legend>
# <span> <label class="blind" for="stockSearchQuery_1079042">검색어 입력</label> <input class="finance_search_input" id="stockSearchQuery_1079042" name="query" placeholder="종목검색" type="text"/> </span>
# <button class="finance_search_btn nclicks(rig.finance)">종목검색</button>
# <a class="finance_my_link nclicks(rig.finance)" href="https://finance.naver.com/mystock/" target="_blank">마이스톡</a>
# </fieldset>
# </form>
# </div>
# </div>
# <div class="as_finance_more">
# <dl class="as_finance_search_top">
# <dt>
#      검색상위
#     </dt>
# <dd>
# <a class="visit nclicks(rig.finance)" href="https://finance.naver.com/item/main.naver?code=086520" target="_blank">에코프로</a>
# <span>|</span>
# <a class="visit nclicks(rig.finance)" href="https://finance.naver.com/item/main.naver?code=065350" target="_blank">신성델타</a>
# <span>|</span>
# <a class="visit nclicks(rig.finance)" href="https://finance.naver.com/item/main.naver?code=006380" target="_blank">카프로</a>
# </dd>
# </dl>
# </div>
# </div>
# <div id="finance_tab_1" style="display:none">
# <div class="as_finance_content_wrap">
# <div class="as_finance_content">
# <table cellpadding="0" cellspacing="0" class="table_finance_exchange">
# <caption class="blind">
#       환율정보
#      </caption>
# <colgroup>
# <col width="114"/>
# <col/>
# <col width="64"/>
# </colgroup>
# <tbody>
# <tr>
# <th scope="row"><img alt="1 USD" class="icon" height="12" src="https://imgnews.pstatic.net/image/news/2007/new_section/ico_flag_usa.gif" width="19"> 1 USD</img></th>
# <td class="num">1,320.00</td>
# <td class="num up"><i>상승</i>12.50</td>
# </tr>
# <tr>
# <th scope="row"><img alt="1 EUR" class="icon" height="12" src="https://imgnews.pstatic.net/image/news/2007/new_section/ico_flag_europe.gif" width="19"> 1 EUR</img></th>
# <td class="num">1,445.33</td>
# <td class="num up"><i>상승</i>7.60</td>
# </tr>
# <tr>
# <th scope="row"><img alt="100 JPY" class="icon" height="12" src="https://imgnews.pstatic.net/image/news/2007/new_section/ico_flag_japan.gif" width="19"> 100 JPY</img></th>
# <td class="num">922.43</td>
# <td class="num up"><i>상승</i>1.95</td>
# </tr>
# <tr>
# <th scope="row"><img alt="1 CNY" class="icon" height="12" src="https://imgnews.pstatic.net/image/news/2007/new_section/ico_flag_china.gif" width="19"> 1 CNY</img></th>
# <td class="num">182.19</td>
# <td class="num up"><i>상승</i>0.54</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <div class="as_finance_more">
# <dl class="as_finance_time">
# <dt>
#      기준
#     </dt>
# <dd>
#      2023.08.08 22:42
#     </dd>
# </dl>
# <a class="more_link2 nclicks(rig.finance)" href="https://finance.naver.com/marketindex/exchangeMain.naver" target="_blank">환율정보 더보기</a>
# </div>
# </div>
# <script type="text/javascript">
# function stock_search_1079042() {
# var obj = jindo.$('stockSearchQuery_1079042');
# var query = obj.value.replace(/[ ]/g, "");
# obj.value = query;
# if (query == '') {
# alert("검색어를 입력해주세요.");
# return false;
# }
# }
# function fund_search_1079042() {
# var obj = jindo.$('fundSearchQuery_1079042');
# var query = obj.value.replace(/[ ]/g, "");
# obj.value = query;
# if (query == '') {
# alert("검색어를 입력해주세요.");
# return false;
# }
# }
# function finance_tab() {
# jindo.$('tab_0').onmouseover = function () {
# var pst = 0;
# for(var i=0 ; i<2; i++) {
# var liObj = jindo.$('tab_'+i);
# var AObjInliObj = liObj.querySelector('a');
# if (i == pst) {
# liObj.className = "on";
# AObjInliObj.innerHTML = "<strong>"+liObj.innerText+"</strong>";
# AObjInliObj.setAttribute('aria-selected', true);
# jindo.$('finance_tab_'+i).style.display = '';
# } else {
# liObj.className = "";
# if ( liObj.textContent != null) {
# AObjInliObj.textContent = AObjInliObj.textContent.replace("<strong>", "").replace("</strong>", "");
# }
# AObjInliObj.setAttribute('aria-selected', false);
# jindo.$('finance_tab_'+i).style.display = 'none';
# }
# }
# }
# jindo.$('tab_1').onmouseover = function () {
# var pst = 1;
# for(var i=0 ; i<2; i++) {
# var liObj = jindo.$('tab_'+i);
# var AObjInliObj = liObj.querySelector('a');
# if (i == pst) {
# liObj.className = "on";
# AObjInliObj.innerHTML = "<strong>"+liObj.innerText+"</strong>";
# AObjInliObj.setAttribute('aria-selected', true);
# jindo.$('finance_tab_'+i).style.display = '';
# } else {
# liObj.className = "";
# if ( liObj.textContent != null) {
# AObjInliObj.textContent = AObjInliObj.textContent.replace("<strong>", "").replace("</strong>", "");
# }
# AObjInliObj.setAttribute('aria-selected', false);
# jindo.$('finance_tab_'+i).style.display = 'none';
# }
# }
# }
# }
# function finance_tab_focus(el) {
# if(event.keyCode == '13') {
# jindo.$('tab_0').className = '';
# jindo.$('tab_0').querySelector('a').setAttribute('aria-selected', false);
# jindo.$('finance_tab_'+0).style.display = 'none';
# jindo.$('tab_1').className = '';
# jindo.$('tab_1').querySelector('a').setAttribute('aria-selected', false);
# jindo.$('finance_tab_'+1).style.display = 'none';
# var liObj = jindo.$(el.parentElement);
# liObj.className = 'on';
# liObj.querySelector('a').setAttribute('aria-selected', true);
# jindo.$('finance_'+liObj.id).style.display = '';
# }
# }
# function setOnOff(id) {
# var imageOn = "https://ssl.pstatic.net/static.news/image/news/admin/btn_on.gif";
# var imageOff = "https://ssl.pstatic.net/static.news/image/news/admin/btn_off.gif";
# var imageObj = jindo.$("onOffBtn_"+id);
# var imageObjSrc = imageObj.src;
# var enableValue = "";
# if (imageObjSrc.indexOf('on') > 0) {
# imageValue = imageOff;
# enableValue = "off";
# } else if (imageObjSrc.indexOf('off') > 0) {
# imageValue = imageOn;
# enableValue = "on";
# }
# Copyright.setOnOff(id, enableValue, processOnOff);
# imageObj.src = imageValue;
# }
# finance_tab();
# </script>
# </div>
# <div class="section" id="right_dailyList" style="margin-bottom:20px; white-space:nowrap;">
# <h4>분야별 주요뉴스</h4>
# <div class="classfy sd" style="display:block">
# <ul class="list_txt">
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/437/0000354566?sid=103" title=' "BTS가 국격 높이도록…" 잼버리 지원 요청한 국회의원[D:이슈]'> "BTS가 국격 높이도록…" 잼버리 지원 요청한 국회의원[D:이슈]</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/011/0004224100?sid=100" title="여야, 이동관 청문회 18일 개최키로">여야, 이동관 청문회 18일 개최키로</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/008/0004922450?sid=100" title="'비명계' 반발 때문?...野혁신위, '대의원제 개편안' 발표 이틀 연기">'비명계' 반발 때문?...野혁신위, '대의원제 개편안' 발표 이틀 연기</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001920398?sid=104" title="태풍 '카눈' 일본 규슈 접근...최대 400㎜ 폭우 예상">태풍 '카눈' 일본 규슈 접근...최대 400㎜ 폭우 예상</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/015/0004877240?sid=104" title='"20년 후 미국서 태어난 아이들은…" 놀라운 전망 나왔다'>"20년 후 미국서 태어난 아이들은…" 놀라운 전망 나왔다</a>
# </li>
# </ul>
# <ul class="list_txt">
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/277/0005297302?sid=101" title="위례 A1-5BL 분양원가 3.3㎡당 1236만원…수익률 37.9%">위례 A1-5BL 분양원가 3.3㎡당 1236만원…수익률 37.9%</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/366/0000922706?sid=101" title="전경련 새 회장에 류진…첫 성과는 ‘4대 그룹 복귀’ 될 듯">전경련 새 회장에 류진…첫 성과는 ‘4대 그룹 복귀’ 될 듯</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001920380?sid=101" title='산업부 "예상보다 높은 최대 전력 수요...긴장감 갖고 관리"'>산업부 "예상보다 높은 최대 전력 수요...긴장감 갖고 관리"</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/629/0000231829?sid=105" title="'아이폰15' 언제 나오나…&quot;다음 달 12일 공개, 22일부터 판매 전망&quot;">'아이폰15' 언제 나오나…"다음 달 12일 공개, 22일부터 판매 전망"</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/092/0002301309?sid=105" title="넷마블 '에이지오브타이탄', 정식 출시 D-1...사전 다운로드">넷마블 '에이지오브타이탄', 정식 출시 D-1...사전 다운로드</a>
# </li>
# </ul>
# <ul class="list_txt">
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/648/0000018566?sid=101" title="SPC안전위가 점검했던 샤니공장서 또 끼임 사고">SPC안전위가 점검했던 샤니공장서 또 끼임 사고</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/437/0000354618?sid=102" title="'이재명 대표 테러 협박' 일본발 이메일…경비 강화·폭발물 수색(종합)">'이재명 대표 테러 협박' 일본발 이메일…경비 강화·폭발물 수색(종합)</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/056/0011541236?sid=100" title="불법 선거운동 혐의 신경호 강원교육감, 오늘 첫 공판">불법 선거운동 혐의 신경호 강원교육감, 오늘 첫 공판</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003383483?sid=103" title="클래식계 ‘엄친아’ 오텐잠머가 소개하는 번스타인의 세계">클래식계 ‘엄친아’ 오텐잠머가 소개하는 번스타인의 세계</a>
# </li>
# <li>
# <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/277/0005297391?sid=103" title="혼다, '더 커진' 대형 SUV 파일럿 완전변경 모델 사전계약">혼다, '더 커진' 대형 SUV 파일럿 완전변경 모델 사전계약</a>
# </li>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174933298_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/algorithm"> <img alt="알고리즘 안내" src="https://imgnews.pstatic.net/image/upload/item/2023/07/06/183901500_banner_AI.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2023/06/23/195359666_banner_24hours.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/unfairArticleList.naver?mid=omb"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
# headline 뉴스 추출
# class : sh_text
head_line = bs_obj.findAll('div', {'class':'sh_text'})
len(head_line)
head_line[0]
# Out:
# 10
# <div class="sh_text">
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/009/0005170036?sid=101">공정위·권익위까지 총동원해 조사 … 與 "LH 카르텔 철폐 입법 속도"</a>
# <div class="sh_text_lede">당정, 입주민 불안 달래기 입찰담합 조사·공익신고 접수 '철근 누락' 시공사 13곳 부당 하도급까지 조사 확대 ◆ LH 부실시공 후폭풍 ◆ 정부가 철근 누락 등 부실 시공으로 드러난 건설업계의 '이권 나눠먹 …</div>
# <div class="sh_text_info _rcount" data-comment="{gno:'news009,0005170036',params:{sid1:'101'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="sh_text_press">매일경제</div>
# <a class="sh_head_more nclicks(cls_eco.clstitle)" href="/main/clusterArticles.naver?id=c_202308071210_00000010&amp;mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=009&amp;aid=0005170036"><span class="sh_head_more_icon_num">46</span><span class="blind">개의 관련뉴스 더보기</span></a>
# </div>
# </div>

# %%
head_line[0].find('a')  # 기사제목
head_line[0].find('a')['href']  # 헤드라인 뉴스 중 하나의 전체기사 링크
head_line[0].find('a').text  # 헤드라인 뉴스 제목
# Out:
# <a class="sh_text_headline nclicks(cls_eco.clsart)" href="https://n.news.naver.com/mnews/article/009/0005170036?sid=101">공정위·권익위까지 총동원해 조사 … 與 "LH 카르텔 철폐 입법 속도"</a>
# 'https://n.news.naver.com/mnews/article/009/0005170036?sid=101'
# '공정위·권익위까지 총동원해 조사 … 與 "LH 카르텔 철폐 입법 속도"'

# %%
head_line[0].find('div', {'class':"sh_text_lede"}).text  # 뉴스 내용 요약
# Out:
# "당정, 입주민 불안 달래기 입찰담합 조사·공익신고 접수 '철근 누락' 시공사 13곳 부당 하도급까지 조사 확대 ◆ LH 부실시공 후폭풍 ◆ 정부가 철근 누락 등 부실 시공으로 드러난 건설업계의 '이권 나눠먹 …"

# %%
# 전체 헤드라인의 title, link, desc 출력
for head in head_line :
    a_t = head.find('a')
    div_t = head.find('div', {'class':"sh_text_lede"})
    print(a_t.text," : ", a_t['href']," : ", div_t.text)  # 제목, 링크, description
# Out:
# 공정위·권익위까지 총동원해 조사 … 與 "LH 카르텔 철폐 입법 속도"  :  https://n.news.naver.com/mnews/article/009/0005170036?sid=101  :  당정, 입주민 불안 달래기 입찰담합 조사·공익신고 접수 '철근 누락' 시공사 13곳 부당 하도급까지 조사 확대 ◆ LH 부실시공 후폭풍 ◆ 정부가 철근 누락 등 부실 시공으로 드러난 건설업계의 '이권 나눠먹 …
# 美 금리 인하…시장은 내년 3월 vs 연준은 내년 하반기[오미주]  :  https://n.news.naver.com/mnews/article/008/0004922821?sid=101  :  '오미주'는 '오늘 주목되는 미국 주식'의 줄인 말입니다. 주가에 영향을 미칠 만한 이벤트나 애널리스트들의 언급이 많았던 주식을 뉴욕 증시 개장 전에 정 …
# 편의점 이익 줄었지만 슈퍼·호텔 선전…GS리테일, 2분기 영업익 94% '껑충' [종합]  :  https://n.news.naver.com/mnews/article/015/0004877450?sid=101  :  편의점(GS25)과 슈퍼마켓(GS더프레시), 홈쇼핑(GS샵) 등을 운영하는 종합유통기업 GS리테일이 올해 2분기 영업이익 기준으로 증권가 예상을 큰 폭으 …
# 오전에 떴던 초전도체 테마株, 오후에 '와르르'  :  https://n.news.naver.com/mnews/article/009/0005169978?sid=101  :  LK-99는 초전도체 아니다" 美메릴랜드대 연구소 발표 서남 22% 오르다 하한가로 금감원장 "테마주 과열돼" 허위풍문 집중 점검 예고 초전도체 테마주가 …
# 차기 KB금융 회장 1차 후보 6명 오늘 확정...`용퇴` 윤종규, “이사회가 탁월한 후보 선임할 것”  :  https://n.news.naver.com/mnews/article/029/0002818151?sid=101  :  '명예로운 퇴진'을 선언한 윤종규 KB금융회장이 "이사회가 그룹의 지속 성장을 이끌 탁월한 후보를 선임할 것"이라는 기대감을 담은 서한을 주요 주주들에게 …
# '소비 절벽 여파' 현대백화점, 2분기 영업이익 21.9%↓(종합)  :  https://n.news.naver.com/mnews/article/018/0005547086?sid=101  :  현대백화점(069960)이 고물가에 꺾인 소비 심리와 지난해 호실적에 따른 역기저 효과 여파로 2분기 매출과 영업이익이 모두 줄었다. 다만 하반기부터 면 …
# 2분기 제조업 국내 공급 1.6% 감소...수입 3년 만에 감소세 전환  :  https://n.news.naver.com/mnews/article/052/0001920444?sid=101  :  올해 2분기 제조업 제품의 국내 공급이 1년 전보다 감소한 것으로 나타났습니다. 수입 제품 공급은 3년 만에 감소세로 돌아섰습니다. 통계청은 지난 2분기 제조업 국내 공급지수가 지난해 같은 기간보다 1.6% …
# 진에어, 2Q 영업익 178억 흑자 전환…상반기 '역대 최대'  :  https://n.news.naver.com/mnews/article/003/0012020204?sid=101  :  진에어는 별도기준 올 2분기 실적으로 매출액 2590억원, 영업이익 178억원을 달성했다고 8일 공시했다. 매출액은 전년동기대비 105% 증가했고, 영업 …
# LG엔솔, 中에 배터리 재활용공장 짓는다  :  https://n.news.naver.com/mnews/article/014/0005054391?sid=101  :  LG에너지솔루션이 중국 1위 코발트 생산업체 화유코발트와 배터리 리사이클 합작법인(JV)를 설립했다. LG에너지솔루션은 지난 7일 중국 저장성에 위치한 화유코발트 본사에서 배터리 리사이클 합작법인 계약 체결 …
# 항공유 판매, 코로나 이전 수준 회복  :  https://n.news.naver.com/mnews/article/015/0004877555?sid=101  :  정유 4사 수익성의 한 축을 담당하는 항공유 판매가 코로나19 이전 수준으로 회복하고 있다. 항공유 판매는 각사 매출의 10~15%에 불과하지만, 정제마 …

# %%
# 예외처리
# 전체 헤드라인의 title, link, desc 출력
for head in head_line :
    try :  # 실제 진행되어야 하는 코드
        a_t = head.find('a')
        div_t = head.find('div',{'class':"sh_text_lede"})
        print(a_t.text," : ", a_t['href']," : ", div_t.text)
    except :
        print('에러발생')
# Out:
# 공정위·권익위까지 총동원해 조사 … 與 "LH 카르텔 철폐 입법 속도"  :  https://n.news.naver.com/mnews/article/009/0005170036?sid=101  :  당정, 입주민 불안 달래기 입찰담합 조사·공익신고 접수 '철근 누락' 시공사 13곳 부당 하도급까지 조사 확대 ◆ LH 부실시공 후폭풍 ◆ 정부가 철근 누락 등 부실 시공으로 드러난 건설업계의 '이권 나눠먹 …
# 美 금리 인하…시장은 내년 3월 vs 연준은 내년 하반기[오미주]  :  https://n.news.naver.com/mnews/article/008/0004922821?sid=101  :  '오미주'는 '오늘 주목되는 미국 주식'의 줄인 말입니다. 주가에 영향을 미칠 만한 이벤트나 애널리스트들의 언급이 많았던 주식을 뉴욕 증시 개장 전에 정 …
# 편의점 이익 줄었지만 슈퍼·호텔 선전…GS리테일, 2분기 영업익 94% '껑충' [종합]  :  https://n.news.naver.com/mnews/article/015/0004877450?sid=101  :  편의점(GS25)과 슈퍼마켓(GS더프레시), 홈쇼핑(GS샵) 등을 운영하는 종합유통기업 GS리테일이 올해 2분기 영업이익 기준으로 증권가 예상을 큰 폭으 …
# 오전에 떴던 초전도체 테마株, 오후에 '와르르'  :  https://n.news.naver.com/mnews/article/009/0005169978?sid=101  :  LK-99는 초전도체 아니다" 美메릴랜드대 연구소 발표 서남 22% 오르다 하한가로 금감원장 "테마주 과열돼" 허위풍문 집중 점검 예고 초전도체 테마주가 …
# 차기 KB금융 회장 1차 후보 6명 오늘 확정...`용퇴` 윤종규, “이사회가 탁월한 후보 선임할 것”  :  https://n.news.naver.com/mnews/article/029/0002818151?sid=101  :  '명예로운 퇴진'을 선언한 윤종규 KB금융회장이 "이사회가 그룹의 지속 성장을 이끌 탁월한 후보를 선임할 것"이라는 기대감을 담은 서한을 주요 주주들에게 …
# '소비 절벽 여파' 현대백화점, 2분기 영업이익 21.9%↓(종합)  :  https://n.news.naver.com/mnews/article/018/0005547086?sid=101  :  현대백화점(069960)이 고물가에 꺾인 소비 심리와 지난해 호실적에 따른 역기저 효과 여파로 2분기 매출과 영업이익이 모두 줄었다. 다만 하반기부터 면 …
# 2분기 제조업 국내 공급 1.6% 감소...수입 3년 만에 감소세 전환  :  https://n.news.naver.com/mnews/article/052/0001920444?sid=101  :  올해 2분기 제조업 제품의 국내 공급이 1년 전보다 감소한 것으로 나타났습니다. 수입 제품 공급은 3년 만에 감소세로 돌아섰습니다. 통계청은 지난 2분기 제조업 국내 공급지수가 지난해 같은 기간보다 1.6% …
# 진에어, 2Q 영업익 178억 흑자 전환…상반기 '역대 최대'  :  https://n.news.naver.com/mnews/article/003/0012020204?sid=101  :  진에어는 별도기준 올 2분기 실적으로 매출액 2590억원, 영업이익 178억원을 달성했다고 8일 공시했다. 매출액은 전년동기대비 105% 증가했고, 영업 …
# LG엔솔, 中에 배터리 재활용공장 짓는다  :  https://n.news.naver.com/mnews/article/014/0005054391?sid=101  :  LG에너지솔루션이 중국 1위 코발트 생산업체 화유코발트와 배터리 리사이클 합작법인(JV)를 설립했다. LG에너지솔루션은 지난 7일 중국 저장성에 위치한 화유코발트 본사에서 배터리 리사이클 합작법인 계약 체결 …
# 항공유 판매, 코로나 이전 수준 회복  :  https://n.news.naver.com/mnews/article/015/0004877555?sid=101  :  정유 4사 수익성의 한 축을 담당하는 항공유 판매가 코로나19 이전 수준으로 회복하고 있다. 항공유 판매는 각사 매출의 10~15%에 불과하지만, 정제마 …

# %% [markdown]
# ### 수집한 data를 DataFrame으로 생성

# %%
# 빈리스트 생성
headline_title=[]
headline_link=[]
headline_desc=[]

# %%
for head in head_line :
    try : 
        a_t = head.find('a')
        div_t = head.find('div',{'class':"sh_text_lede"})
        headline_title.append(a_t.text)
        headline_link.append(a_t['href'])
        headline_desc.append(div_t.text)
    except :
        print('에러발생')

# %%
headline_df = pd.DataFrame({'기사제목':headline_title,
                            '기사링크':headline_link,
                            '기사요약':headline_desc})
headline_df.head()
# Out:
#                                                 기사제목  \
# 0            공정위·권익위까지 총동원해 조사 … 與 "LH 카르텔 철폐 입법 속도"
# 1               美 금리 인하…시장은 내년 3월 vs 연준은 내년 하반기[오미주]
# 2  편의점 이익 줄었지만 슈퍼·호텔 선전…GS리테일, 2분기 영업익 94% '껑충' [종합]
# 3                         오전에 떴던 초전도체 테마株, 오후에 '와르르'
# 4  차기 KB금융 회장 1차 후보 6명 오늘 확정...`용퇴` 윤종규, “이사회가 탁월...
#
#                                                 기사링크  \
# 0  https://n.news.naver.com/mnews/article/009/000...
# 1  https://n.news.naver.com/mnews/article/008/000...
# 2  https://n.news.naver.com/mnews/article/015/000...
# 3  https://n.news.naver.com/mnews/article/009/000...
# 4  https://n.news.naver.com/mnews/article/029/000...
#
#                                                 기사요약
# 0  당정, 입주민 불안 달래기 입찰담합 조사·공익신고 접수 '철근 누락' 시공사 13곳...
# 1  '오미주'는 '오늘 주목되는 미국 주식'의 줄인 말입니다. 주가에 영향을 미칠 만한...
# 2  편의점(GS25)과 슈퍼마켓(GS더프레시), 홈쇼핑(GS샵) 등을 운영하는 종합유통...
# 3  LK-99는 초전도체 아니다" 美메릴랜드대 연구소 발표 서남 22% 오르다 하한가로...
# 4  '명예로운 퇴진'을 선언한 윤종규 KB금융회장이 "이사회가 그룹의 지속 성장을 이끌...
